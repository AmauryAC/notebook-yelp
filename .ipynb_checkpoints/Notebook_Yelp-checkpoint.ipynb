# %%
# Desativando os avisos sobre as bibliotecas depreciadas:
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# !pip3 install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\amaur_5j86jzh\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\amaur_5j86jzh\anaconda3\lib\site-packages (from imblearn) (0.6.2)
# Requirement already satisfied: numpy>=1.11 in c:\users\amaur_5j86jzh\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.14.0)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\amaur_5j86jzh\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in c:\users\amaur_5j86jzh\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (0.14.1)
# Requirement already satisfied: scipy>=0.17 in c:\users\amaur_5j86jzh\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.0.0)

# %%
# !pip3 install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.0.2-py3-none-win_amd64.whl (24.6 MB)
# Requirement already satisfied: numpy in c:\users\amaur_5j86jzh\anaconda3\lib\site-packages (from xgboost) (1.14.0)
# Requirement already satisfied: scipy in c:\users\amaur_5j86jzh\anaconda3\lib\site-packages (from xgboost) (1.0.0)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.0.2

# %%
# Importando os módulos:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score

# %%
# Importando os modelos:
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
import xgboost as xgb

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.feature_selection import mutual_info_classif, mutual_info_regression, SelectKBest, SelectPercentile, chi2

# %%
def loadData(filepath):
    chunks = []
    for chunk in pd.read_csv(filepath, low_memory=False, chunksize=1000):
        chunks.append(chunk)
    return chunks

# %%
df_business = pd.concat(loadData('C:/Users/amaur_5j86jzh/Desktop/TCC - Yelp/Datasets/yelp_business.csv'))

# %%
df_business_att = pd.concat(loadData('C:/Users/amaur_5j86jzh/Desktop/TCC - Yelp/Datasets/yelp_business_attributes.csv'))

# %%
df_checkin = pd.concat(loadData('C:/Users/amaur_5j86jzh/Desktop/TCC - Yelp/Datasets/yelp_checkin.csv'))

# %%
df_review = pd.concat(loadData('C:/Users/amaur_5j86jzh/Desktop/TCC - Yelp/Datasets/yelp_review.csv'))

# %%
df_business_cols = ['business_id', 'name', 'latitude', 'longitude', 'city', 'state', 'stars', 'review_count', 'is_open']
df_checkin_cols = ['business_id', 'checkins']
df_review_cols = ['business_id', 'stars', 'text']

# %%
new_df_business = df_business.loc[:, df_business_cols]
new_df_checkin = df_checkin.loc[:, df_checkin_cols]
new_df_review = df_review.loc[:, df_review_cols]

# %%
df_review_group = new_df_review.groupby(by='business_id')

grouped_df_review = pd.DataFrame()
grouped_df_review['stars_mean'] = df_review_group['stars'].mean()

# %%
df_checkin_group = new_df_checkin.groupby(by='business_id')

grouped_df_checkin = pd.DataFrame()
grouped_df_checkin['total_checkins'] = df_checkin_group['checkins'].sum()

# %%
grouped_df_review.reset_index(inplace=True)
grouped_df_checkin.reset_index(inplace=True)

df = pd.merge(left=grouped_df_review, right=grouped_df_checkin, on='business_id', how='left')
df = pd.merge(left=new_df_business, right=df, on='business_id', how='left')
#df = pd.merge(left=df, right=df_business_att,on='business_id',how='left')
df
# Out:
#                    business_id  \
# 0       FYWN1wneV18bWNgQjJ2GNg
# 1       He-G7vWjzVUysIKrfNbPUQ
# 2       KQPW8lFf1y5BT2MxiSZ3QA
# 3       8DShNS-LuFqpEWIp0HxijA
# 4       PfOCPjBrlQAnz__NXj9h_w
# 5       o9eMRCWt5PkpLDE0gOPtcQ
# 6       kCoE3jvEtg6UVz5SOD3GVw
# 7       OD2hnuuTJI9uotcKycxg1A
# 8       EsMcGiZaQuG1OOvL9iUFug
# 9       TGWhGNusxyMaA4kQVBNeew
# 10      XOSRcvtaKc_Q5H1SAzN20A
# 11      Y0eMNa5C-YU1RQOZf9XvVA
# 12      xcgFnd-MwkZeO5G2HQ0gAQ
# 13      NmZtoE3v8RdSJEczYbMT9g
# 14      fNMVV_ZX7CJSDWQGdOM8Nw
# 15      l09JfMeQ6ynYs5MCJtrcmQ
# 16      IQSlT5jGE6CCDhSG0zG3xg
# 19                            "Maxim Bakery & Restaurant"  43.867565
# 20                                            "Starbucks"  43.639863
# 21                                                  "Fye"  33.380133
# 22      "TSA Checkpoint T-4 A - Phoenix Sky Harbor Int...  33.435463
# 23                                     "GoodLife Fitness"  43.592753
# 24                                          "Sportster's"  43.682867
# 25                               "Chula Taberna Mexicana"  43.669256
# 26                                    "Alfredo's Jewelry"  36.085051
# 27                                            "DAVIDsTEA"  43.656729
# 28                                         "Panera Bread"  41.343078
# 29                                           "Toast Cafe"  35.047287
# ...                                                   ...        ...
# 174537                                           "Isobar"  55.975580
# 174538                                   "Flair Cleaners"  36.275588
# 174539                   "Stonegate Real Estate Services"  36.134355
# 174540                    "Tanner Materials Tile & Stone"  33.318047
# 174541                              "Duquesne University"  40.436981
# 174542                             "Goodyear Endodontics"  33.360239
# 174543                                 "Urban House Cafe"  43.666034
# 174544                      "Sweet Serendipity Bake Shop"  43.682054
# 174545                                        "Starbucks"  36.173589
# 174546                                     "Sprint Store"  36.055130
# 174547                             "Swim Platforms, Inc."  33.416962
# 174548                                        "Badgarten"  48.898590
# 174549                                 "Last Drop Tavern"  55.947855
# 174550                                        "Hot Topic"  40.544559
# 174551                                           "Target"  40.522828
# 174552                             "9 Dragons Fight Shop"  36.128780
# 174553                                              "CVS"  35.322669
# 174554                                      "Eos Fitness"  33.291521
# 174555                                       "Otto Onkel"  48.764212
# 174556                                       "L'Occitane"  36.150022
# 174557                                   "Virgin America"  43.681727
# 174558                        "Floridino's Pizza & Pasta"  33.311383
# 174559                              "Luxe Appeal Studios"  33.495350
# 174560                                    "Copie Express"  45.504628
# 174561                             "Nuno's Churrasqueira"  43.649789
# 174562                                    "Whitby Toyota"  43.873460
# 174563                                "Village Auto Body"  41.243385
# 174564                                              "AAM"  33.407914
# 174565                      "Bronze Beauty Spray Tanning"  40.517724
# 174566                                 "Phoenix Pharmacy"  33.479861
#
#          longitude             city state  stars  review_count  is_open  \
# 0      -111.978599        Ahwatukee    AZ    4.0            22        1
# 1       -80.104900         McMurray    PA    3.0            11        1
# 2      -112.115310          Phoenix    AZ    1.5            18        1
# 3      -111.964725            Tempe    AZ    3.0             9        0
# 4       -81.475690   Cuyahoga Falls    OH    3.5           116        1
# 5         9.147950        Stuttgart    BW    4.0             5        1
# 6      -115.268460        Las Vegas    NV    4.0             5        1
# 7      -115.249660        Las Vegas    NV    1.5             9        1
# 8       -80.091349          Wexford    PA    5.0            15        1
# 9      -115.046350        Henderson    NV    5.0             7        1
# 10      -80.212815          Houston    PA    4.5             3        0
# 11     -111.791257         Chandler    AZ    5.0            23        1
# 12      -79.260153          Markham    ON    4.0            38        1
# 13      -79.887916        Homestead    PA    2.0             5        1
# 14      -80.839345        Charlotte    NC    3.5             7        1
# 15      -79.399339          Toronto    ON    3.0            12        0
# 16     -112.240012           Peoria    AZ    3.0            20        1
# 17      -89.262047      Sun Prairie    WI    3.5             9        1
# 18     -112.347038         Goodyear    AZ    5.0            65        1
# 19      -79.412662    Richmond Hill    ON    3.5            34        1
# 20      -79.419533          Toronto    ON    4.0            21        1
# 21     -111.788768             Mesa    AZ    4.5             4        0
# 174543    3.968750             1.0
# 174544    4.545455             1.0
# 174545    2.400000             2.0
# 174546    3.857143             1.0
# 174547    5.000000             1.0
# 174548    3.238095             1.0
# 174549    3.633333             2.0
# 174550    4.000000             1.0
# 174551    3.375000             1.0
# 174552    5.000000             1.0
# 174553    2.000000             1.0
# 174554    2.812500             3.0
# 174555    2.884615             1.0
# 174556    3.333333             1.0
# 174557    3.600000             1.0
# 174558    4.104278             2.0
# 174559    3.823529             1.0
# 174560    3.000000             NaN
# 174561    3.000000             NaN
# 174562    4.000000             1.0
# 174563    5.000000             NaN
# 174564    1.631579             1.0
# 174565    5.000000             1.0
# 174566    4.750000             1.0
#
# [174567 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174567 entries, 0 to 174566
# Data columns (total 11 columns):
# business_id       174567 non-null object
# name              174567 non-null object
# latitude          174566 non-null float64
# longitude         174566 non-null float64
# city              174567 non-null object
# state             174567 non-null object
# stars             174567 non-null float64
# review_count      174567 non-null int64
# is_open           174567 non-null int64
# stars_mean        174567 non-null float64
# total_checkins    146350 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 16.0+ MB

# %%
#business_cats=';'.join(df['categories'])
#cats=pd.DataFrame(business_cats.split(';'),columns=['category'])
#cats_ser = cats.category.value_counts()

#cats_df = pd.DataFrame(cats_ser)
#cats_df.reset_index(inplace=True)

#cats_df
# Out:
#                              index  category
# 0                      Restaurants     54618
# 1                         Shopping     27971
# 2                             Food     24777
# 3                    Beauty & Spas     17014
# 4                    Home Services     16205
# 5                 Health & Medical     14230
# 6                        Nightlife     12154
# 7                   Local Services     11232
# 8                       Automotive     11052
# 9                             Bars     10563
# 10       Event Planning & Services      9078
# 11                     Active Life      8257
# 12                         Fashion      7019
# 13                      Sandwiches      6345
# 14                       Fast Food      6280
# 15                     Hair Salons      6140
# 16          American (Traditional)      6097
# 17                           Pizza      6067
# 18                    Coffee & Tea      5936
# 19                 Hotels & Travel      5736
# 20            Arts & Entertainment      5515
# 21                   Home & Garden      5379
# 22                     Auto Repair      5172
# 23                         Doctors      4838
# 24           Professional Services      4752
# 25                         Italian      4662
# 26                     Real Estate      4611
# 27                         Burgers      4558
# 28              Breakfast & Brunch      4497
# 29                     Nail Salons      4294
# ...                            ...       ...
# 1264                       Tempura         1
# 1265                          Soba         1
# 1266                   Agriturismi         1
# 1267                   Makerspaces         1
# 1268                    Otologists         1
# 1269  Undersea/Hyperbaric Medicine         1
# 1270                         Minho         1
# 1271                           Wok         1
# 1272            Rotisserie Chicken         1
# 1273                  Municipality         1
# 1274               Registry Office         1
# 1275              Dialysis Clinics         1
# 1276                         Rodeo         1
# 1277                      Tonkatsu         1
# 1278                   DUI Schools         1
# 1279                       Mystics         1
# 1280                     Town Hall         1
# 1281             Signature Cuisine         1
# 1282                      Playsets         1
# 1283                     Guamanian         1
# 1284               Customs Brokers         1
# 1285                        Hainan         1
# 1286                 Toxicologists         1
# 1287             Hybrid Car Repair         1
# 1288                  Hang Gliding         1
# 1289                    Osteopaths         1
# 1290                        Linens         1
# 1291                      Palatine         1
# 1292                      Sicilian         1
# 1293          Hong Kong Style Cafe         1
#
# [1294 rows x 2 columns]

# %%
df.describe()
# Out:
#             latitude      longitude          stars   review_count  \
# count  174567.000000  174567.000000  174567.000000  174567.000000
# mean       38.627342     -92.678934       3.632196      19.120659
# std         5.389011      26.240022       1.003739      23.040539
# min       -36.086009    -142.466650       1.000000       3.000000
# 25%        33.631550    -112.125877       3.000000       4.000000
# 50%        36.144262     -89.410122       3.500000       8.000000
# 75%        43.606209     -79.657592       4.500000      23.000000
# max        89.999314     115.086769       5.000000      80.000000
#
#              is_open     stars_mean  total_checkins
# count  174567.000000  174567.000000   174567.000000
# mean        0.840376       3.631343        1.361282
# std         0.366258       0.995509        1.779979
# min         0.000000       1.000000        0.000000
# 25%         1.000000       3.000000        1.000000
# 50%         1.000000       3.714286        1.000000
# 75%         1.000000       4.400000        1.000000
# max         1.000000       5.000000       14.546321

# %%
def checkNullQuantity(df):
    return df.isnull().sum()

checkNullQuantity(df)
# Out:
# business_id           0
# name                  0
# latitude              1
# longitude             1
# city                  0
# state                 0
# stars                 0
# review_count          0
# is_open               0
# stars_mean            0
# total_checkins    28217
# dtype: int64

# %%
df.loc[df['city'].isnull(), 'city'] = 'Edinburgh'

# %%
df.loc[df['state'].isnull(), 'city'] = 'Henderson'
df.loc[df['state'].isnull(), 'state'] = 'NV'

# %%
df.loc[df['longitude'].isnull(), 'longitude'] = -79.65156555
df.loc[df['latitude'].isnull(), 'latitude'] = 43.78596696

# %%
df['total_checkins'] = df['total_checkins'].fillna(0)

# %%
checkNullQuantity(df)
# Out:
# business_id       0
# name              0
# latitude          0
# longitude         0
# city              0
# state             0
# stars             0
# review_count      0
# is_open           0
# stars_mean        0
# total_checkins    0
# dtype: int64

# %%
#Verificar outliers

def plot_boxplot(nrows, ncols, index, df, column):
    plt.subplot(nrows, ncols, index)
    fig = sns.boxplot(x=column, data=df, orient='v')
    fig.set_title('BoxPlot: {}'.format(column))
    fig.set_ylabel('Values')
    
def plot_distribution(nrows, ncols, index, df, column):
    plt.subplot(nrows, ncols, index)
    fig = df[column].hist(bins=25)
    fig.set_title('Distribution: {}'.format(column))
    fig.set_ylabel('Values')

# %%
plt.figure(figsize=(15, 7))

plot_boxplot(1, 2, 1, df, 'review_count')
plot_boxplot(1, 2, 2, df, 'total_checkins')

# %%
plt.figure(figsize=(15, 7))

plot_distribution(1, 2, 1, df, 'review_count')
plot_distribution(1, 2, 2, df, 'total_checkins')

# %%
def get_outliers_limits(df, column):
    q1 = df[column].quantile(q=0.25)
    q3 = df[column].quantile(q=0.75)
    amp = q3 - q1
    lim_max = q3 + 3 * amp
    lim_min = q1 - 3 * amp
    return [lim_min, lim_max]

def get_outliers(df, column, lim_min, lim_max):
    return df[(df[column] > lim_max) | (df[column] < lim_min)]

def show_counted_outliers(df, column, lim_min, lim_max):
    print('{}: {}'.format(column, get_outliers(df, column, lim_min, lim_max)[column].count()))

# %%
review_count_limits = get_outliers_limits(df, 'review_count')
total_checkins_limits = get_outliers_limits(df, 'total_checkins')

print('review_count: {}'.format(review_count_limits))
print('total_checkins: {}'.format(total_checkins_limits))
# Out:
# review_count: [-53.0, 80.0]
# total_checkins: [1.0, 1.0]

# %%
show_counted_outliers(df, 'review_count', review_count_limits[0], review_count_limits[1])
show_counted_outliers(df, 'total_checkins', total_checkins_limits[0], total_checkins_limits[1])
# Out:
# review_count: 13246
# total_checkins: 62671

# %%
total_checkins_new_limit = df['total_checkins'].mean() + 3 * df['total_checkins'].std()

show_counted_outliers(df, 'total_checkins', 0, total_checkins_new_limit)
# Out:
# total_checkins: 1208

# %%
df.loc[df['review_count'] > review_count_limits[1], 'review_count'] = review_count_limits[1]
df.loc[df['total_checkins'] > total_checkins_new_limit, 'total_checkins'] = total_checkins_new_limit

# %%
by_state = df.groupby('state')
states = by_state['business_id'].count()
states = states.loc[states > 10].index

by_city = df.groupby('city')
cities = by_city['business_id'].count()
cities = cities.loc[cities > 10].index
# Out:
# Index(['AZ', 'BW', 'C', 'CHE', 'EDH', 'ELN', 'ESX', 'FIF', 'HLD', 'IL', 'MLN',
#        'NC', 'NV', 'NY', 'NYK', 'OH', 'ON', 'PA', 'QC', 'SC', 'ST', 'WI',
#        'WLN'],
#       dtype='object', name='state')

# %%
df.loc[!df['state'] in states, 'state'] = 'Other'
# Out:
#   File "<ipython-input-299-190eb1bf752b>", line 1
#     df.loc[!df['state'] isin states, 'state'] = 'Other'
#            ^
# SyntaxError: invalid syntax

# %%
# Dados raros
by_state = df.groupby('state')
by_state_count = by_state['business_id'].count()

by_city = df.groupby('city')
by_city_count = by_state['business_id'].count()

df.loc[df['state'].count() < 100, 'state'] = 'Other'
df.loc[df['city'].count() < 100, 'city'] = 'Other'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-208-9ea1022de98b> in <module>()
#       1 # Dados raros
# ----> 2 df.loc[df['state'].count() < 100, 'state'] = 'Other'
#       3 df.loc[df['city'].count() < 100, 'city'] = 'Other'
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     192             key = com._apply_if_callable(key, self.obj)
#     193         indexer = self._get_setitem_indexer(key)
# --> 194         self._setitem_with_indexer(indexer, value)
#     195
#     196     def _has_valid_type(self, k, axis):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     373                     self.obj.is_copy = None
#     374
# --> 375                     nindexer.append(labels.get_loc(key))
#     376
#     377                 else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: False

# %%
state_ordinal = {j: i for i, j in enumerate(df['state'].unique(), 0)}
df['state'] = df['state'].map(state_ordinal)

# %%
city_ordinal = {k: i for i, k in enumerate(df['city'].unique(), 0)}
df['city'] = df['city'].map(city_ordinal)

# %%
df['is_open'].value_counts()
# Out:
# 1    146702
# 0     27865
# Name: is_open, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='is_open',data=df);

# %%
#df_cols = ['latitude', 'longitude', 'review_count', 'starsMean', 'TotalCheckins']
df_cols = ['latitude', 'longitude', 'review_count', 'starsMean', 'TotalCheckins', 'city', 'state']

X = df[df_cols]
y = df['is_open']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1, stratify=y)

# %%
lr = LogisticRegression()

lr.fit(X_train, y_train)

lr
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5544709683576229

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.57      0.56     36675
#            1       0.56      0.53      0.55     36676
#
#     accuracy                           0.55     73351
#    macro avg       0.55      0.55      0.55     73351
# weighted avg       0.55      0.55      0.55     73351

# %%
print(pd.crosstab(y_test, y_pred, rownames=['Real'], colnames=['Predito'], margins=True))
# Out:
# Predito     0     1    All
# Real
# 0        4432  2534   6966
# 1         999  5968   6967
# All      5431  8502  13933

# %%
#Aplicando NearMiss
nr = NearMiss()

X, y = nr.fit_sample(X, y)
ax = sns.countplot(x=y)

# %%
#Aplicando o SMOTE
smt = SMOTE()

X, y = smt.fit_sample(X, y)
ax = sns.countplot(x=y)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-0.98574931, -0.70256308, -0.09636115, ..., -0.06274614,
#         -0.45501345, -1.14651912],
#        [ 0.25017961,  0.48931793, -0.22655639, ..., -0.06274614,
#         -0.33343899, -0.83072998],
#        [ 0.87546958,  0.51985363, -0.03126352, ..., -0.06274614,
#         -0.23212694,  0.43242656],
#        ...,
#        [-0.93667037, -0.70423974, -0.22655639, ..., -0.06274614,
#          0.01102198, -1.14651912],
#        [ 0.47955517,  0.43470697, -0.22655639, ..., -0.63675175,
#          0.31495813, -0.51494085],
#        [-0.65870842,  0.46358956, -0.22655639, ..., -0.63675175,
#         -0.25238935,  0.74821569]])

# %%
modelo_v1 = sm.Logit(df['is_open'], df[['latitude', 'longitude', 'review_count', 'starsMean', 'TotalCheckins']]);
modelo_v2 = modelo_v1.fit(method='bfgs')

modelo_v2.pvalues
# Out:
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# Optimization terminated successfully.
#          Current function value: 0.437265
#          Iterations: 17
#          Function evaluations: 32
#          Gradient evaluations: 26
# latitude         6.357029e-272
# longitude         7.161172e-48
# review_count      2.011656e-64
# starsMean        5.345768e-145
# TotalCheckins     7.885458e-15
# dtype: float64

# %%
valor_p = chi2(df[['state', 'city']], df['is_open'])
valor_p[1]
# Out:
# array([5.59529898e-10, 0.00000000e+00])

# %%
mi = mutual_info_classif(X, y)
mi
# Out:
# array([0.08435017, 0.0809416 , 0.13788505, 0.14260069, 0.07803759,
#        0.05540705, 0.01695353])

# %%
mi = pd.Series(mi)
mi.index = X.columns
mi = mi.sort_values(ascending=False)
mi.plot.bar(figsize=(12,8))
plt.title('Mutual Information')
# Out:
# Text(0.5,1,'Mutual Information')

# %%
mi = mutual_info_classif(X_scaled, y)
mi
# Out:
# array([0.08433175, 0.0818191 , 0.14233372, 0.14158761, 0.07608486,
#        0.05722931, 0.02068335])

# %%
mi = pd.Series(mi)
mi.index = X.columns
mi = mi.sort_values(ascending=False)
mi.plot.bar(figsize=(12,8))
plt.title('Mutual Information com escala')
# Out:
# Text(0.5,1,'Mutual Information com escala')

# %%
num_folds = 10
num_instances = len(X)
seed = 7

# %%
modelos = []
modelos.append(('LR', LogisticRegression()))
modelos.append(('LDA', LinearDiscriminantAnalysis()))
modelos.append(('NB', GaussianNB()))
modelos.append(('KNN', KNeighborsClassifier()))
modelos.append(('CART', DecisionTreeClassifier()))
modelos.append(('ADA', AdaBoostClassifier()))
modelos.append(('GBM', GradientBoostingClassifier()))
modelos.append(('RF', RandomForestClassifier()))
modelos.append(('XGB', xgb.XGBClassifier()))
modelos.append(('SVM', SVC()))

# %%
#avaliando cada modelo

resultados = []
nomes = []

for nome, modelo in modelos:
    kfold = model_selection.KFold(n_splits = num_folds, random_state = seed, shuffle = True)
    cv_results = model_selection.cross_val_score(modelo, X, y, cv = kfold, scoring = 'accuracy')
    resultados.append(cv_results)
    nomes.append(nome)
    msg = "%s: %f (%f)" % (nome, cv_results.mean(), cv_results.std() )
    print(msg)
# Out:
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\amaur_5j86jzh\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LR: 0.757294 (0.004359)
# LDA: 0.663269 (0.003951)
# NB: 0.701148 (0.006053)
# KNN: 0.771021 (0.004551)
# CART: 0.734452 (0.006142)
# ADA: 0.778773 (0.004794)
# GBM: 0.795478 (0.005196)
# RF: 0.783582 (0.005364)
# XGB: 0.807949 (0.004902)
# SVM: 0.748825 (0.005345)
